# %%
from Modelo import Modelo

modelo = Modelo("global_cancer_patients_2015_2024.csv", "MDL")
# Out:
# MSE (por fold): [0.32041806700016806, 0.31124845594397205, 0.31314174847181137, 0.3132401949068919, 0.3084225513545507]
# MSE médio: 0.31329420353547877
# R² (por fold): [0.7744912350690218, 0.7836481532166637, 0.7824196500260515, 0.7869681396536639, 0.7836932528455913]
# R² médio: 0.7822440861621984

# %%
from Modelo import Modelo

modelo = Modelo("global_cancer_patients_2015_2024.csv", "DTR")
# Out:
# MSE (por fold): [0.41935631481837354, 0.4091934820656835, 0.41660230711375934, 0.4102629744411678, 0.41806019423355795]
# MSE médio: 0.4146950545345084
# R² (por fold): [0.7048589503517344, 0.7155656073277006, 0.7105321273061556, 0.7209838133883105, 0.7068008148812465]
# R² médio: 0.7117482626510294

# %%
from Modelo import Modelo

modelo = Modelo("global_cancer_patients_2015_2024.csv", "SVR")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 modelo = Modelo("global_cancer_patients_2015_2024.csv", "SVR")
#
# NameError: name 'Modelo' is not defined

# %%
vec = [85,2.8,4.8,4.4,0.3,8.9, 3, 3]
modelo.predicao(vec)
# Out:
# [3.83405899]
# /home/lucas_of/anaconda3/envs/NLP/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from Dados import Dados

dados = Dados("global_cancer_patients_2015_2024.csv")

# %%
dados.correlacao()
# Out:
#                             Age    Gender  Country_Region      Year  \
# Age                    1.000000  0.000866        0.008048 -0.002505
# Gender                 0.000866  1.000000        0.003745 -0.003964
# Country_Region         0.008048  0.003745        1.000000  0.002639
# Year                  -0.002505 -0.003964        0.002639  1.000000
# Genetic_Risk           0.002229  0.001788        0.000919  0.009942
# Air_Pollution          0.001101 -0.003600       -0.002643  0.000649
# Alcohol_Use           -0.004130  0.004085        0.004876  0.001934
# Smoking                0.001734  0.001722        0.005443 -0.006209
# Obesity_Level         -0.002706  0.002059        0.001076 -0.002441
# Cancer_Type           -0.001803 -0.005456       -0.000559 -0.000409
# Cancer_Stage          -0.003309 -0.003681        0.000923 -0.011968
# Treatment_Cost_USD     0.003591  0.002705       -0.003682  0.000061
# Survival_Years        -0.000147 -0.002696        0.005121  0.000018
# Target_Severity_Score -0.001481  0.001130        0.005800  0.002109
#
#                        Genetic_Risk  Air_Pollution  Alcohol_Use   Smoking  \
# Age                        0.002229       0.001101    -0.004130  0.001734
# Gender                     0.001788      -0.003600     0.004085  0.001722
# Country_Region             0.000919      -0.002643     0.004876  0.005443
# Year                       0.009942       0.000649     0.001934 -0.006209
# Genetic_Risk               1.000000      -0.004492    -0.002558 -0.003718
# Air_Pollution             -0.004492       1.000000     0.003511  0.003549
# Alcohol_Use               -0.002558       0.003511     1.000000 -0.002938
# Smoking                   -0.003718       0.003549    -0.002938  1.000000
# Obesity_Level              0.003522       0.006507     0.007425  0.005828
# Cancer_Type               -0.005100       0.004025     0.002083  0.003463
# Cancer_Stage              -0.006454      -0.004490     0.000933  0.001968
# Treatment_Cost_USD        -0.002365      -0.007566    -0.003608 -0.009169
# Survival_Years             0.001708       0.000893    -0.000527  0.001371
# Target_Severity_Score      0.478700       0.366963     0.363250  0.484420
#
#                        Obesity_Level  Cancer_Type  Cancer_Stage  \
# Age                        -0.002706    -0.001803     -0.003309
# Gender                      0.002059    -0.005456     -0.003681
# Country_Region              0.001076    -0.000559      0.000923
# Year                       -0.002441    -0.000409     -0.011968
# Genetic_Risk                0.003522    -0.005100     -0.006454
# Air_Pollution               0.006507     0.004025     -0.004490
# Alcohol_Use                 0.007425     0.002083      0.000933
# Smoking                     0.005828     0.003463      0.001968
# Obesity_Level               1.000000     0.009007      0.006415
# Cancer_Type                 0.009007     1.000000     -0.001668
# Cancer_Stage                0.006415    -0.001668      1.000000
# Treatment_Cost_USD         -0.001251     0.000712     -0.002605
# Survival_Years              0.009771    -0.001717     -0.003014
# Target_Severity_Score       0.251366     0.003244     -0.000722
#
#                        Treatment_Cost_USD  Survival_Years  \
# Age                              0.003591       -0.000147
# Gender                           0.002705       -0.002696
# Country_Region                  -0.003682        0.005121
# Year                             0.000061        0.000018
# Genetic_Risk                    -0.002365        0.001708
# Air_Pollution                   -0.007566        0.000893
# Alcohol_Use                     -0.003608       -0.000527
# Smoking                         -0.009169        0.001371
# Obesity_Level                   -0.001251        0.009771
# Cancer_Type                      0.000712       -0.001717
# Cancer_Stage                    -0.002605       -0.003014
# Treatment_Cost_USD               1.000000       -0.000429
# Survival_Years                  -0.000429        1.000000
# Target_Severity_Score           -0.466058        0.004161
#
#                        Target_Severity_Score
# Age                                -0.001481
# Gender                              0.001130
# Country_Region                      0.005800
# Year                                0.002109
# Genetic_Risk                        0.478700
# Air_Pollution                       0.366963
# Alcohol_Use                         0.363250
# Smoking                             0.484420
# Obesity_Level                       0.251366
# Cancer_Type                         0.003244
# Cancer_Stage                       -0.000722
# Treatment_Cost_USD                 -0.466058
# Survival_Years                      0.004161
# Target_Severity_Score               1.000000
